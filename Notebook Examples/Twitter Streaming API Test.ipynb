# %%
import sqlite3
import tweepy
import json
import sqlite3

# %%
consumer_key = "4yLfbC723iTMdpVuMG4sUIbgy"
consumer_secret = "WbztNPnzgWJNRpvwSuC6ViDyXNDwtjfKsSl5d6hBhbc1FDPE1t"
access_token = "955855581360910337-NxKQ23Q033lhuemZlFGyFUb5TaoiYqr"
access_token_secret = "qlqToJDCA9KgAHvuE8AnszPKf23MowZAHUk7xs0tVeBMQ"

# %%
# conn = sqlite3.connect('Tweets.db')
# c = conn.cursor()
# c.execute('''CREATE TABLE tweets
#     (tweetText text,
#     user text,
#     followers integer,
#     date text,
#     location text)''')
# conn.commit()
# conn.close()

# %%
global api

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# DB stuff
conn = sqlite3.connect('Tweets.db')
c = conn.cursor()

# %%
class Tweet():

    # Data on the tweet
    def __init__(self, text, user, followers, date, location):
        self.text = text
        self.user = user
        self.followers = followers
        self.date = date
        self.location = location

    # Inserting that data into the DB
    def insertTweet(self):

        c.execute("INSERT INTO tweets (tweetText, user, followers, date, location) VALUES (?, ?, ?, ?, ?)",
            (self.text, self.user, self.followers, self.date, self.location))
        conn.commit()

# %%
class TweetStreamListener(tweepy.StreamListener):

    # When data is received
    def on_data(self, data):

        # Error handling because teachers say to do this
        try:

            # Make it JSON
            tweet = json.loads(data)

            # filter out retweets
            if not tweet['retweeted'] and 'RT @' not in tweet['text']:

                # Get user via Tweepy so we can get their number of followers
                user_profile = api.get_user(tweet['user']['screen_name'])

                # assign all data to Tweet object
                tweet_data = Tweet(
                    str(tweet['text'].encode('utf-8')),
                    tweet['user']['screen_name'],
                    user_profile.followers_count,
                    tweet['created_at'],
                    tweet['user']['location'])

                # Insert that data into the DB
                tweet_data.insertTweet()
                print("Another sweet sweet tweet inserted into database")

        # Let me know if something bad happens
        except Exception as e:
            print(e)
            pass

        return True

# %%
if __name__ == '__main__':

    # Run the stream!
    l = TweetStreamListener()
    stream = tweepy.Stream(auth, l)

    # Filter the stream for these keywords. Add whatever you want here!
    stream.filter(track=['Trump'])
# Out:
# Another sweet sweet tweet inserted into database
# Another sweet sweet tweet inserted into database
# Another sweet sweet tweet inserted into database
# Another sweet sweet tweet inserted into database

# %%
import pandas as pd

# %%
df = pd.read_sql_query("select * from tweets limit 20000;", conn)

# %%
len(df)
# Out:
# 250

# %%
df
# Out:
#                                              tweetText             user  \
# 0    b'@SueNKGifTWriter Vous dite pamela et trump. ...  LeChapelierFou7
# 1    b'@RyanAFournier Of course not. She\xe2\x80\x9...  Steve_Tatarunis
# 2     b'#ImpeachmentInquiryNow #ImpeachDonaldTrumpNOW'   ladygingermint
# 3    b'@RealBasedMAGA @USAloveGOD @realDonaldTrump ...       sgrandmont
# 4    b'@GentlemanGeorge @Jag11814459 @VeuveK @roseb...  JohnRya13591294
# 5    b'@AlbertoRodNews el se\xc3\xb1or Abrams le sa...       marcocol66
# 6    b"OMG....wtf is wrong with people.....get over...  DeplorableSunny
# 7    b'honestly, this is like ppl who claim trump c...   ivysaintstyles
# 8              b'#QAnon. Q stands for Quite the Moran'         Scr0dman
# 9    b'Siemens CEO says Trump is becoming the \xe2\...     cassady2euca
# 10   b'@POTUS @realDonaldTrump you should make sure...     ChopnWoodUGA
# 11   b'@DonaldJTrumpJr In a statement last week, U....           vbpers
# 12   b"Ben Carson points to Trump's policies as pro...     popsfisherhl
# 13   b'@NoBahTee_ @krztfr68 @NumbersMean @stevenwai...           PD3598
# 14   b'Trump is becoming more hawkish on Iran \xe2\...      chrisdanne2
# 15   b'@mattgaetz @realDonaldTrump Americans have s...   BonnieBlue1960
# 16   b'@IvankaTrump Hi,my name is wupeng from china...             lqqq
# 17   b'ICE is Gestapo. These hateful agencies must ...         CarolK47
# 18                                  b'GETTIN IT DONE.'   warrenjsmith50
# 19                          b'https://t.co/sm4H4jl9BQ'       jamieob256
# 20                                       b'LIES!!!!!!'          Black_1
# 21   b"So what is President Trump doing right?  It'...    keyboardbrian
# 22   b'@dannymcintosh @BHPIII13 @gtconway3d You mea...          DfkaraG
# 23   b'I agree.  Pelosi , Congress. Do your damn JO...   JamesWilsonJr1
# 24   b"@VImpmon @dantesoccer100 @DlVlD7 @AP This is...          atronic
# 25   b'@Ryan23051951 @cwebbonline @realDonaldTrump ...        dgsixkado
# 26                             b'Damn Freakin Skippy!'       jjresearch
# 27   b'@IlhanMN Sorry, you anti-American clown. I\'...    DrScottPayne2
# 28   b"@RepAdamSchiff The only reason Trump won was...  Gregory28718301
# 29   b'Do we really care what this person thinks ab...  TCarrol79823223
# ..                                                 ...              ...
# 220                                          b'Wtf???'       adhithya35
# 221  b'@madarassi @rohini_sgh @narendramodi Wow sha...  MonaLis16830170
# 222  b'@cmclymer @malkatz No way Joey would vote fo...   theresa_basile
# 223  b'Trump expands fast-track deportation authori...             WESH
# 224  b'No one yanked your chain Fido. \xf0\x9f\x90\...   StepheniePauze
# 225  b'HERE WE GO! Trump Prepping to Make Monster C...       ezridersos
# 226  b'@shaunking The \xe2\x80\x9cpussy grabber, ch...   feedingthreads
# 227  b'@politico Welcome to the mob family Devin. Y...  Stephen67265483
# 228  b'@sharonf1001 @Aprylsmithts @AntiGOPActivist ...        jake_brum
# 229  b'@GOP @KellyannePolls Folks dont believe the ...     Evilgenius68
# 230  b'@LizRNC How many days since trump drafted hi...     KnopeforPres
# 231  b'It\xe2\x80\x99s no longer about whether Trum...        swede1956
# 232  b'@catturd2 @C_3C_3 Nonsensical Squad not offe...    VickieLFisher
# 233                         b'https://t.co/T8lUjw6dEU'       bythesea66
# 234  b'@realDonaldTrump @trish_regan totally guilty...        1Badastre
# 235  b"Husband's hot take on the Trump Pelosi budge...  antipinterester
# 236  b'@realDonaldTrump  Quienes m\xc3\xa0s necesit...    delfinazul119
# 237  b'Watch the rock!!!!since u never did mix with...  HenryDa17582997
# 238  b'@shaunhannity\nInvestigate the number of cou...        bobball68
# 239  b'Rashida Tlaib: Why I disrupted Donald Trump ...      mennekinpis
# 240  b'https://t.co/98NPJFscKZ https://t.co/WhnzdJ0...      tweakyourpc
# 241  b'@hruodlandvs @IMAO_ @benshapiro To Trump it ...  TheRealJohnDias
# 242  b'@anitaDlivaditis When Does America Reckon wi...      19Jackson90
# 243  b'#RacistRapistPresident #EpsteinsLittleBlackB...        Lava1Nuno
# 244  b'#Trump #PresidentTrump #Trump2020 #Trump2020...    RealRedDebate
# 245  b"True, plus he IS the best President of all t...          hfox707
# 246                          b'Have no words for Beto'   ElizabethWard2
# 247  b'@politicususa Every single person Trump appo...        pjavahead
# 248                   b'@SpeakerPelosi \n@RepCummings'      Tupelohny14
# 249                b'@melgigberg Donald trump be like'     KoraUniverse
#
#      followers                            date  \
# 0           46  Mon Jul 22 22:48:18 +0000 2019
# 1          838  Mon Jul 22 22:48:18 +0000 2019
# 2          114  Mon Jul 22 22:48:18 +0000 2019
# 3         2606  Mon Jul 22 22:48:18 +0000 2019
# 4          163  Mon Jul 22 22:48:18 +0000 2019
# 5          205  Mon Jul 22 22:48:18 +0000 2019
# 6         7114  Mon Jul 22 22:48:18 +0000 2019
# 7         1530  Mon Jul 22 22:48:18 +0000 2019
# 8           48  Mon Jul 22 22:48:19 +0000 2019
# 9         4960  Mon Jul 22 22:48:19 +0000 2019
# 10         554  Mon Jul 22 22:48:19 +0000 2019
# 11           4  Mon Jul 22 22:48:19 +0000 2019
# 12        1067  Mon Jul 22 22:48:19 +0000 2019
# 13         294  Mon Jul 22 22:48:19 +0000 2019
# 14         522  Mon Jul 22 22:48:19 +0000 2019
# 15          54  Mon Jul 22 22:48:19 +0000 2019
# 16          12  Mon Jul 22 22:48:19 +0000 2019
# 17         442  Mon Jul 22 22:48:19 +0000 2019
# 18        1382  Mon Jul 22 22:48:20 +0000 2019
# 19        1843  Mon Jul 22 22:48:20 +0000 2019
# 20         388  Mon Jul 22 22:48:20 +0000 2019
# 21         624  Mon Jul 22 22:48:20 +0000 2019
# 22          38  Mon Jul 22 22:48:20 +0000 2019
# 23         460  Mon Jul 22 22:48:20 +0000 2019
# 24         702  Mon Jul 22 22:48:21 +0000 2019
# 25         288  Mon Jul 22 22:48:21 +0000 2019
# 26         713  Mon Jul 22 22:48:21 +0000 2019
# 27        1123  Mon Jul 22 22:48:21 +0000 2019
# 28          34  Mon Jul 22 22:48:21 +0000 2019
# 29           1  Mon Jul 22 22:48:21 +0000 2019
# ..         ...                             ...
# 220        882  Tue Jul 23 03:35:48 +0000 2019
# 221          1  Tue Jul 23 03:35:48 +0000 2019
# 222       1700  Tue Jul 23 03:35:49 +0000 2019
# 223     205817  Tue Jul 23 03:35:48 +0000 2019
# 224      18436  Tue Jul 23 03:35:49 +0000 2019
# 225      11744  Tue Jul 23 03:35:49 +0000 2019
# 226         33  Tue Jul 23 03:35:49 +0000 2019
# 227          7  Tue Jul 23 03:35:49 +0000 2019
# 228        540  Tue Jul 23 03:35:49 +0000 2019
# 229       2115  Tue Jul 23 03:35:50 +0000 2019
# 230        217  Tue Jul 23 03:35:50 +0000 2019
# 231       7573  Tue Jul 23 03:35:50 +0000 2019
# 232       2862  Tue Jul 23 03:35:50 +0000 2019
# 233       1096  Tue Jul 23 03:35:50 +0000 2019
# 234         61  Tue Jul 23 03:35:50 +0000 2019
# 235        390  Tue Jul 23 03:35:50 +0000 2019
# 236        940  Tue Jul 23 03:35:51 +0000 2019
# 237          7  Tue Jul 23 03:35:51 +0000 2019
# 238          0  Tue Jul 23 03:35:51 +0000 2019
# 239       1968  Tue Jul 23 03:35:51 +0000 2019
# 240       4771  Tue Jul 23 03:35:50 +0000 2019
# 241         10  Tue Jul 23 03:35:51 +0000 2019
# 242        495  Tue Jul 23 03:35:51 +0000 2019
# 243       3772  Tue Jul 23 03:35:51 +0000 2019
# 244        673  Tue Jul 23 03:35:51 +0000 2019
# 245       3508  Tue Jul 23 03:35:52 +0000 2019
# 246       2912  Tue Jul 23 03:35:52 +0000 2019
# 247        112  Tue Jul 23 03:35:52 +0000 2019
# 248         61  Tue Jul 23 03:35:52 +0000 2019
# 249          0  Tue Jul 23 03:35:52 +0000 2019
#
#                                               location
# 0                                                  Dtc
# 1                                     New England, USA
# 2                                  San Luis Obispo, CA
# 3                                                 None
# 4                                  Cúige Mumhan,  Éire
# 5                                    Coral Springs, FL
# 6                                                 None
# 7                                      Bordéus, França
# 8                                                   FL
# 9                                       Columbus, Ohio
# 10                                        West Georgia
# 11                                                None
# 12                                                  CA
# 13                                       United States
# 14                                gainesville, florida
# 15                                     California, USA
# 16                                                None
# 17                                                None
# 18                             Stoke-on-Trent, England
# 19                                        New York, NY
# 20                                        Grove Street
# 21                                       Rochester, NY
# 22                                                None
# 23                                       Nashville, TN
# 24                                         Oakland, CA
# 25                                          Maine, USA
# 26                                        New York, NY
# 27                                         Houston, TX
# 28                                                None
# 29                                        Stamford, CT
# ..                                                 ...
# 220                                               None
# 221                                               None
# 222                                      New York City
# 223                            Orlando - Daytona Beach
# 224                                               Ky.
# 225                                          Iowa, USA
# 226                                      United States
# 227                                        Seattle, WA
# 228                                               None
# 229                                                 Al
# 230                                               None
# 231                             Arlington Heights, IL.
# 232                                    Washington, USA
# 233                                                 CA
# 234                                               None
# 235                                         Dallas, TX
# 236                                             México
# 237                     677 West Main St. Box 821  388
# 238                                               None
# 239                                      New York, USA
# 240                                               None
# 241                                               None
# 242                                      Hampton Roads
# 243                                        Nacitoches
# 244                                           #America
# 245  USA . MAGA  Married over 50 yrs to HS Sweethea...
# 246                                         California
# 247                                               None
# 248                                               None
# 249                                            Hell no
#
# [250 rows x 5 columns]
